# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/Insiya24/datasets/main/WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
df
# Out:
#       Age Attrition              Department  DistanceFromHome EducationField  \
# 0      41       Yes                   Sales                 1  Life Sciences
# 1      49        No  Research & Development                 8  Life Sciences
# 2      37       Yes  Research & Development                 2          Other
# 3      33        No  Research & Development                 3  Life Sciences
# 4      27        No  Research & Development                 2        Medical
# ...   ...       ...                     ...               ...            ...
# 1465   36        No  Research & Development                23        Medical
# 1466   39        No  Research & Development                 6        Medical
# 1467   27        No  Research & Development                 4  Life Sciences
# 1468   49        No                   Sales                 2        Medical
# 1469   34        No  Research & Development                 8        Medical
#
# ...

# %%
df.head()
# Out:
#    Age Attrition              Department  DistanceFromHome EducationField  \
# 0   41       Yes                   Sales                 1  Life Sciences
# 1   49        No  Research & Development                 8  Life Sciences
# 2   37       Yes  Research & Development                 2          Other
# 3   33        No  Research & Development                 3  Life Sciences
# 4   27        No  Research & Development                 2        Medical
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0            1.0             1.0                      2.0  Female        94.0
# 1            1.0             2.0                      3.0    Male        61.0
# 2            1.0             4.0                      4.0    Male        92.0
# 3            1.0             5.0                      4.0  Female        56.0
# 4            NaN             7.0                      1.0    Male        40.0
#
# ...

# %%
df.dtypes
# Out:
# Age                           int64
# Attrition                    object
# Department                   object
# DistanceFromHome              int64
# EducationField               object
# EmployeeCount               float64
# EmployeeNumber              float64
# EnvironmentSatisfaction     float64
# Gender                       object
# HourlyRate                  float64
# JobInvolvement              float64
# JobLevel                    float64
# JobSatisfaction             float64
# MaritalStatus                object
# MonthlyIncome                 int64
# MonthlyRate                   int64
# OverTime                     object
# PercentSalaryHike           float64
# PerformanceRating             int64
# RelationshipSatisfaction      int64
# StandardHours                 int64
# TotalWorkingYears             int64
# WorkLifeBalance               int64
# YearsAtCompany                int64
# YearsSinceLastPromotion       int64
# dtype: object

# %%
df_EF=df.groupby(["Department"])[["EducationField"]]

# %%
print(df_EF)

# %%
df.tail()
# Out:
#       Age Attrition              Department  DistanceFromHome EducationField  \
# 1465   36        No  Research & Development                23        Medical
# 1466   39        No  Research & Development                 6        Medical
# 1467   27        No  Research & Development                 4  Life Sciences
# 1468   49        No                   Sales                 2        Medical
# 1469   34        No  Research & Development                 8        Medical
#
#       EmployeeCount  EmployeeNumber  EnvironmentSatisfaction Gender  \
# 1465            1.0          2061.0                      3.0   Male
# 1466            1.0          2062.0                      4.0   Male
# 1467            1.0          2064.0                      2.0   Male
# 1468            1.0          2065.0                      4.0   Male
# 1469            1.0          2068.0                      2.0   Male
#
#       HourlyRate  ...  MonthlyRate  OverTime  PercentSalaryHike  \
# ...

# %%
df.isnull()
# Out:
#         Age  Attrition  Department  DistanceFromHome  EducationField  \
# 0     False      False       False             False           False
# 1     False      False       False             False           False
# 2     False      False       False             False           False
# 3     False      False       False             False           False
# 4     False      False       False             False           False
# ...     ...        ...         ...               ...             ...
# 1465  False      False       False             False           False
# 1466  False      False       False             False           False
# 1467  False      False       False             False           False
# 1468  False      False       False             False           False
# 1469  False      False       False             False           False
#
#       EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# ...

# %%
df['EmployeeCount'].mean()
# Out:
# 1.0

# %%
df['EnvironmentSatisfaction'].mean()
# Out:
# 2.722940776038121

# %%
df['PercentSalaryHike'].mean()
# Out:
# 15.220628415300546

# %%
df['YearsSinceLastPromotion'].mean()
# Out:
# 2.1877551020408164

# %%
df['YearsAtCompany'].mean()
# Out:
# 7.0081632653061225

# %%
df['EmployeeCount'].fillna(1.0,inplace=True)

# %%
df['EnvironmentSatisfaction'].fillna(2.722940776038121,inplace=True)

# %%
df['PercentSalaryHike'].fillna(15.220628415300546,inplace=True)

# %%
df['YearsSinceLastPromotion'].fillna(7.0081632653061225,inplace=True)

# %%
df.fillna(df.mode().iloc[0], inplace=True)

# %%
from sklearn import preprocessing

le=preprocessing.LabelEncoder()

# %%
df["Attrition"]=le.fit_transform(df["Attrition"])

# %%
df["Department"]=le.fit_transform(df["Department"])

# %%
df["EducationField"]=le.fit_transform(df["EducationField"])

# %%
df["Gender"]=le.fit_transform(df["Gender"])

# %%
df["OverTime"]=le.fit_transform(df["OverTime"])

# %%
df["MaritalStatus"]=le.fit_transform(df["MaritalStatus"])

# %%
import seaborn
import matplotlib.pyplot as pt
pt.figure(figsize=(9,9))
correlation=df.corr()
heatmap=seaborn.heatmap(correlation,annot=True)
pt.show()
